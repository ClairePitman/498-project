# %%
import re
f=open('data/498data/1950data.csv','r')

# %%
f=open('data/498data/2010data.csv','r')
f.readline()
file = open("2010p1.txt", "w")
file2 = open("2010p2.txt", "w")
p = re.compile('\d+,([a-z A-Z]+),\d+,([\d.]+)')
i=1
for l in f.readlines():
    
    m=p.match(l)
    if(m):
        file.write("{'name':'"+m.group(1)+"','species':'Canis dingo','class':'mammalia','age':"+m.group(2)+"},")
        file2.write("{'source':"+str(i)+",'target':0,'age':"+m.group(2)+"},")
        i=i+1
        print m.groups(1)
#file.close()
#f.close()
# Out:
# ('WORLD', '28.5')
# ('More developed regions', '39.9')
# ('Less developed regions', '26.4')
# ('Least developed countries', '19.3')
# ('AFRICA', '19.2')
# ('Eastern Africa', '17.5')
# ('Burundi', '17.7')
# ('Comoros', '19.1')
# ('Djibouti', '22')
# ('Eritrea', '18.3')
# ('Ethiopia', '17.5')
# ('Kenya', '18.5')
# ('Madagascar', '18')
# ('Malawi', '16.9')
# ('Mauritius', '33.3')
# ('Mayotte', '17.3')
# ('Mozambique', '17.2')
# ('Rwanda', '17.8')
# ('Seychelles', '31.6')
# ('Somalia', '16.1')
# ('South Sudan', '18.3')
# ('Uganda', '15.5')
# ('United Republic of Tanzania', '17.4')
# ('Zambia', '16.5')
# ('Zimbabwe', '18.5')
# ('Middle Africa', '17.1')
# ('Angola', '16')
# ('Cameroon', '18')
# ('Central African Republic', '19.3')
# ('Chad', '15.5')
# ('Congo', '18.9')
# ('Democratic Republic of the Congo', '17.1')
# ('Equatorial Guinea', '20.2')
# ('Gabon', '20.5')
# ('Sao Tome and Principe', '19')
# ('Northern Africa', '24.3')
# ('Algeria', '26')
# ('Egypt', '24.4')
# ('Libya', '25.6')
# ...
